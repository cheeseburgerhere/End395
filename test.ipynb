# %%
import pandas as pd
df=pd.read_csv("data.csv")

# %%
df
# Out:
#     Pallet ID Product type  Product amount (ni)  Size type (si) Pallet type  \
# 0           1           P1                  110               1     100×120
# 1           2           P1                   90               1     100×120
# 2           3           P2                  125               1     100×120
# 3           4           P3                   95               2      80×120
# 4           5           P3                  115               1     100×120
# 5           6           P1                   75               2      80×120
# 6           7           P3                  135               1     100×120
# 7           8           P2                  100               1     100×120
# 8           9           P3                   90               1     100×120
# 9          10           P2                   90               1     100×120
# 10         11           P1                   80               2      80×120
# ...
